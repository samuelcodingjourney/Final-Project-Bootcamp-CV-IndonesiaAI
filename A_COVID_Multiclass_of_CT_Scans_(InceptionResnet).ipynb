# %% [markdown]
# ##Preparation
# (Install, Import Library, Check Dataset)

# %%
# !pip install efficientnet
# Out:
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (23.2)

# %%
import matplotlib.pyplot as plt
import tensorflow

import numpy as np # linear algebra
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, accuracy_score, recall_score, f1_score, precision_score
from sklearn.model_selection import KFold
import random
import sys
import pandas
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import os
import gc

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.models import Model,load_model, Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Input, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from efficientnet.tfkeras import EfficientNetB2
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Check dataset
from google.colab import drive
drive.mount ('/content/drive')

base_dir = '/content/drive/MyDrive/New_Data_CoV2'
ct_scans = os.listdir(base_dir)
ct_scans
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Healthy', 'Covid', 'Others']

# %%
# Total dataset
total = 0

for i in ct_scans:
    dir = os.path.join(base_dir, i)
    num = len(os.listdir(dir))
    print(i+':', num, 'data')
    total = total + num

print('__________________________________')
print('\nTotal:', total, 'data')
# Out:
# Healthy: 757 data
# Covid: 2188 data
# Others: 1257 data
# __________________________________
#
# Total: 4202 data

# %% [markdown]
# ## Pre-Processing

# %%
# !pip install split-folders
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.10/dist-packages (0.5.1)

# %%
# Split folder to divide the dataset into training, validation, and testing data
import splitfolders
splitfolders.ratio(base_dir, output="./train-test", seed=42, ratio=(.80, 0.1, 0.1))
# Out:
# Copying files: 4202 files [00:29, 143.89 files/s]

# %%
# dataset directory
train_dir = 'train-test/train'
val_dir = 'train-test/val'
test_dir = 'train-test/test'

# %% [markdown]
# ##Data Augmentation (Pre-processing)

# %%
# Hyperparameter Initiation
input_tensor  = Input(shape=(224,224,3))
learning_rate = 0.0001
epochs        = 60
image_size    = (224, 224)
batch_size    = 16

# Data augmentation on training data
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=15,
                    width_shift_range=0.1,
                    height_shift_range=0.1,
                    shear_range=0.2,
                    zoom_range=0.2,
                    horizontal_flip = True,
                    fill_mode='nearest')

# Rescale on validation data
val_datagen = ImageDataGenerator(rescale=1./255)

#flow_from_directory() method takes a path of a directory and generates
# batches of augmented data.

train_generator = train_datagen.flow_from_directory(
                    train_dir,
                    target_size=image_size,
                    batch_size=batch_size,
                    shuffle=True,
                    class_mode='categorical',
                    #subset='training'
)

validation_generator = val_datagen.flow_from_directory(
                    val_dir,
                    target_size=image_size,
                    batch_size=batch_size,
                    shuffle=False,
                    class_mode='categorical',
                    #subset='validation'
)
# Out:
# Found 3360 images belonging to 3 classes.
# Found 418 images belonging to 3 classes.

# %%
labels = [k for k in train_generator.class_indices]
sample_generate = train_generator.__next__()
images = sample_generate[0]
titles = sample_generate[1]
plt.figure(figsize = (20 , 20))

for i in range(15):
    plt.subplot(5 , 5, i+1)
    plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
    plt.imshow(images[i])
    plt.title(f'Class: {labels[np.argmax(titles[i],axis=0)]}')
    plt.axis("off")

# %% [markdown]
# ## Building Models with CNN (Convolutional Neural Network)

# %%
from keras.models import load_model

def getModel():
        base_model = InceptionResNetV2 (input_shape=(256, 256, 3),include_top=False, input_tensor=input_tensor)
        base_model = base_model.output
        model = GlobalAveragePooling2D()(base_model)
        model = Dense(256, activation='relu')(model)
        model = Dropout(0.2)(model)
        model = BatchNormalization()(model)
        model = Dense(3, activation='softmax')(model)
        model = Model(inputs=input_tensor, outputs=model)

        for layer in model.layers:
            layer.trainable = True

            model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(learning_rate=learning_rate),
              metrics=['accuracy'])

        return model

model=getModel()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 111, 111, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 111, 111, 32)         96        ['conv2d[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 111, 111, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_3 (Bat  (None, 109, 109, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 109, 109, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 109, 109, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 109, 109, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 109, 109, 64)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 54, 54, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 54, 54, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 54, 54, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 54, 54, 80)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 52, 52, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 52, 52, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 52, 52, 192)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 25, 25, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 25, 25, 64)           192       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 25, 25, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_8 (Bat  (None, 25, 25, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 25, 25, 96)           288       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 25, 25, 48)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 25, 25, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 25, 25, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 25, 25, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 25, 25, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_7 (Bat  (None, 25, 25, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 25, 25, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, 25, 25, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 25, 25, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 25, 25, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_17 (Ba  (None, 25, 25, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_15 (Ba  (None, 25, 25, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 25, 25, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_14 (Ba  (None, 25, 25, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 25, 25, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 25, 25, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 25, 25, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_23 (Ba  (None, 25, 25, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_21 (Ba  (None, 25, 25, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 25, 25, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 25, 25, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 25, 25, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 25, 25, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 25, 25, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_29 (Ba  (None, 25, 25, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_27 (Ba  (None, 25, 25, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 25, 25, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 25, 25, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 25, 25, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 25, 25, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 25, 25, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_35 (Ba  (None, 25, 25, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_33 (Ba  (None, 25, 25, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 25, 25, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_32 (Ba  (None, 25, 25, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 25, 25, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 25, 25, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 25, 25, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_41 (Ba  (None, 25, 25, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_39 (Ba  (None, 25, 25, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 25, 25, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_38 (Ba  (None, 25, 25, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 25, 25, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 25, 25, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 25, 25, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_47 (Ba  (None, 25, 25, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_45 (Ba  (None, 25, 25, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 25, 25, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_44 (Ba  (None, 25, 25, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 25, 25, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 25, 25, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 25, 25, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_53 (Ba  (None, 25, 25, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_51 (Ba  (None, 25, 25, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
# ...
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 5, 5, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_194 (B  (None, 5, 5, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_195 (B  (None, 5, 5, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_193 (B  (None, 5, 5, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_196 (B  (None, 5, 5, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_198 (B  (None, 5, 5, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_199 (B  (None, 5, 5, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_197 (B  (None, 5, 5, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_200 (B  (None, 5, 5, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_202 (B  (None, 5, 5, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_203 (B  (None, 5, 5, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_201 (B  (None, 5, 5, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_204 (B  (None, 5, 5, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_2  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)                  393472    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['dense_4[0][0]']
#
#  batch_normalization_205 (B  (None, 256)                  1024      ['dropout_2[0][0]']
#  atchNormalization)
#
#  dense_5 (Dense)             (None, 3)                    771       ['batch_normalization_205[0][0
#                                                                     ]']
#
# ==================================================================================================
# Total params: 54732003 (208.79 MB)
# Trainable params: 54670947 (208.55 MB)
# Non-trainable params: 61056 (238.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ##Callbacks

# %%
# Save output model
model_file_path='./InceptionResNetV2_model.hdf5'

# This callback will stop the training when there is no improvement in
# the val_loss for 20 consecutive epochs
early_stop = EarlyStopping(patience=20,
                          verbose=1,
                          mode='auto')

# Reduce learning rate when a metric has stopped improving.
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,
                                  verbose=1,factor=0.2, min_lr=0.000001)

# save the best model (best Validation Accuracy)
checkpoints = ModelCheckpoint(model_file_path,monitor='val_accuracy',
                                  mode='max',save_best_only=True)

# %% [markdown]
# ##Model Training

# %%
model=getModel()

# fit model
steps_per_epoch=train_generator.n/batch_size
validation_steps=validation_generator.n/batch_size

history = model.fit(
              train_generator,
              steps_per_epoch=steps_per_epoch,  # how many batches will be executed in each epoch
              epochs=epochs,
              validation_data=validation_generator, # displays the accuracy of validation data testing
              validation_steps=validation_steps,  # how many batches will be executed in each epoch
              callbacks=[early_stop,learn_control,checkpoints],
              verbose=1)
# Out:
# Epoch 1/60
# 210/210 [==============================] - ETA: 0s - loss: 0.9113 - accuracy: 0.6304
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 210/210 [==============================] - 191s 472ms/step - loss: 0.9113 - accuracy: 0.6304 - val_loss: 0.6265 - val_accuracy: 0.7033 - lr: 1.0000e-04
# Epoch 2/60
# 210/210 [==============================] - 106s 505ms/step - loss: 0.5862 - accuracy: 0.7679 - val_loss: 0.6599 - val_accuracy: 0.7560 - lr: 1.0000e-04
# Epoch 3/60
# 210/210 [==============================] - 110s 522ms/step - loss: 0.4414 - accuracy: 0.8327 - val_loss: 0.2275 - val_accuracy: 0.9139 - lr: 1.0000e-04
# Epoch 4/60
# 210/210 [==============================] - 101s 478ms/step - loss: 0.3465 - accuracy: 0.8673 - val_loss: 0.5289 - val_accuracy: 0.8565 - lr: 1.0000e-04
# Epoch 5/60
# 210/210 [==============================] - 97s 462ms/step - loss: 0.2704 - accuracy: 0.9009 - val_loss: 0.3487 - val_accuracy: 0.9115 - lr: 1.0000e-04
# Epoch 6/60
# 210/210 [==============================] - 95s 450ms/step - loss: 0.2497 - accuracy: 0.9101 - val_loss: 2.3625 - val_accuracy: 0.8732 - lr: 1.0000e-04
# Epoch 7/60
# 210/210 [==============================] - 98s 468ms/step - loss: 0.2004 - accuracy: 0.9250 - val_loss: 1.0617 - val_accuracy: 0.8971 - lr: 1.0000e-04
# Epoch 8/60
ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.2541 - val_accuracy: 0.9378 - lr: 2.0000e-05
# Epoch 41/60
# 210/210 [==============================] - 97s 461ms/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.3222 - val_accuracy: 0.9187 - lr: 2.0000e-05
# Epoch 42/60
# 210/210 [==============================] - 86s 407ms/step - loss: 0.0234 - accuracy: 0.9943 - val_loss: 0.2138 - val_accuracy: 0.9330 - lr: 2.0000e-05
# Epoch 43/60
# 210/210 [==============================] - 84s 397ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.2717 - val_accuracy: 0.9282 - lr: 2.0000e-05
# Epoch 44/60
# 210/210 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9967
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 210/210 [==============================] - 84s 399ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.1727 - val_accuracy: 0.9522 - lr: 2.0000e-05
# Epoch 45/60
# 210/210 [==============================] - 84s 400ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.2037 - val_accuracy: 0.9426 - lr: 4.0000e-06
# Epoch 46/60
# 210/210 [==============================] - 84s 398ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.1819 - val_accuracy: 0.9545 - lr: 4.0000e-06
# Epoch 47/60
# 210/210 [==============================] - 85s 403ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.1578 - val_accuracy: 0.9569 - lr: 4.0000e-06
# Epoch 48/60
# 210/210 [==============================] - 85s 404ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.1791 - val_accuracy: 0.9545 - lr: 4.0000e-06
# Epoch 49/60
# 210/210 [==============================] - 84s 401ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.1674 - val_accuracy: 0.9569 - lr: 4.0000e-06
# Epoch 50/60
# 210/210 [==============================] - 84s 399ms/step - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.1884 - val_accuracy: 0.9569 - lr: 4.0000e-06
# Epoch 51/60
# 210/210 [==============================] - 84s 398ms/step - loss: 0.0060 - accuracy: 0.9991 - val_loss: 0.2202 - val_accuracy: 0.9402 - lr: 4.0000e-06
# Epoch 52/60
# 210/210 [==============================] - 85s 405ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.2492 - val_accuracy: 0.9402 - lr: 4.0000e-06
# Epoch 53/60
# 210/210 [==============================] - 88s 419ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.1741 - val_accuracy: 0.9569 - lr: 4.0000e-06
# Epoch 54/60
# 210/210 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9988
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-06.
# 210/210 [==============================] - 86s 409ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.1602 - val_accuracy: 0.9569 - lr: 4.0000e-06
# Epoch 54: early stopping

# %% [markdown]
# ##Model Evaluation

# %%
# Plot Model Accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot Model Loss
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(epochs, loss_train,  label='Training Loss')
plt.plot(epochs, loss_val, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Confusion Matrix and Classification Report

# %%
#Load model
model.load_weights(model_file_path)
validation_generator.reset()

# Model evaluation
scores_train = model.evaluate(train_generator,verbose=1)
scores_validation = model.evaluate(validation_generator, verbose=1)
print("Train Accuracy: %.2f%%" % (scores_train[1]*100))
print("Validation Accuracy: %.2f%%" % (scores_validation[1]*100))

# Model Prediction
pred=model.predict(validation_generator, steps=validation_steps, verbose=1)
predicted_class_indices=np.argmax(pred,axis=1)
labels = (validation_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

actual_class = validation_generator.classes
actual = [labels[k] for k in actual_class]
val_labels = [fn.split('/')[0] for fn in actual]

target_names=list(validation_generator.class_indices.keys())

# Confusion Matrix
cm=confusion_matrix(val_labels, predictions)

# Confusion Matrix Figure
fig = sns.heatmap(cm, annot=True, cmap = "Blues")
fig.set(title = 'Confusion Matrix', xlabel='Predicted Labels', ylabel='Ground Truth Labels')
fig.set_xticklabels(target_names,rotation=20)
fig.set_yticklabels(target_names,rotation=20)
plt.figure(figsize=(3,3))
plt.show(fig)

# Classification Report
cr=classification_report(val_labels, predictions, digits=4)
print("\n              ---Classification Report---\n")
print(cr)
# Out:
# 210/210 [==============================] - 62s 294ms/step - loss: 0.1227 - accuracy: 0.9869
# 27/27 [==============================] - 4s 129ms/step - loss: 0.1221 - accuracy: 0.9761
# Train Accuracy: 98.69%
# Validation Accuracy: 97.61%
# 26/26 [==============================] - 6s 107ms/step
#               ---Classification Report---
#
#               precision    recall  f1-score   support
#
#        Covid     0.9953    0.9633    0.9790       218
#      Healthy     0.9487    0.9867    0.9673        75
#       Others     0.9612    0.9920    0.9764       125
#
#     accuracy                         0.9761       418
#    macro avg     0.9684    0.9807    0.9742       418
# weighted avg     0.9767    0.9761    0.9761       418

# %% [markdown]
# ##Testing Model

# %%
# Rescale
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
                 test_dir,
                 target_size=image_size,
                 batch_size=batch_size,
                 class_mode=None,
                 shuffle=False)
test_steps=test_generator.n/batch_size
test_generator.reset()

#Calling the saved model for making predictions
model_file='./InceptionResNetV2_model.hdf5'
tl_img_aug_cnn = load_model(model_file)
pred=tl_img_aug_cnn.predict(test_generator,
                            verbose=1,
                            steps=test_steps)
predicted_class_indices=np.argmax(pred,axis=1)
labels = (test_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
results.to_csv("results_test.csv",index=False)
target_names=list(validation_generator.class_indices.keys())
test_labels = [fn.split('/')[0] for fn in filenames]
cm=confusion_matrix(test_labels,predictions)
print(cm)


#Confussion Matrix Figure
fig = sns.heatmap(cm, annot=True, cmap = "Blues")
fig.set(title = 'Confussion Matrix', xlabel='Predicted Labels', ylabel='Ground Truth Labels')
fig.set_xticklabels(target_names,rotation=20)
fig.set_yticklabels(target_names,rotation=20)
plt.figure(figsize=(3,3))
plt.show(fig)

#Classification Report
cr=classification_report(test_labels, predictions, digits=4)
print("\n              ---Classification Report---\n")
print(cr)
# Out:
# Found 423 images belonging to 3 classes.
# 26/26 [==============================] - 8s 163ms/step
# [[208   4   7]
#  [  0  76   1]
#  [  3   7 117]]
#               ---Classification Report---
#
#               precision    recall  f1-score   support
#
#        Covid     0.9858    0.9498    0.9674       219
#      Healthy     0.8736    0.9870    0.9268        77
#       Others     0.9360    0.9213    0.9286       127
#
#     accuracy                         0.9480       423
#    macro avg     0.9318    0.9527    0.9409       423
# weighted avg     0.9504    0.9480    0.9484       423

# %%
# !zip -r /content/train-test.zip /content/train-test
# Out:
# updating: content/train-test/ (stored 0%)
# updating: content/train-test/val/ (stored 0%)
# updating: content/train-test/val/Healthy/ (stored 0%)
# updating: content/train-test/val/Healthy/Healthy (93).png (deflated 1%)
# updating: content/train-test/val/Healthy/Healthy